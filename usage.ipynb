# %%
from Bli import Bli

# %%
bli = Bli.from_path('./sample-data/DG20220105114235')

# %%
split_blis, qc_image = bli.threshold_split()

# %%
qc_image
# Out:
# <PIL.Image.Image image mode=RGB size=960x960>

# %%
len(split_blis)
# Out:
# 5

# %%
split_blis[1].photograph_tif
# Out:
# <PIL.Image.Image image mode=I;16 size=144x456>

# %%
split_blis[1].animal_numbers
# Out:
# ['3467']
